# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_path = 'D:\coding\Pune_weather_forcasting\src\data\pune.csv'

# %%
df = pd.read_csv(df_path,encoding='utf-8')

df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2009-01-01 00:00:00        31        13           0.0     11.0        6
# 1  2009-01-01 01:00:00        31        13           0.0     11.0        6
# 2  2009-01-01 02:00:00        31        13           0.0     11.0        6
# 3  2009-01-01 03:00:00        31        13           0.0     11.0        6
# 4  2009-01-01 04:00:00        31        13           0.0     11.0        6
#
#    uvIndex.1  moon_illumination  moonrise   moonset  ... WindChillC  \
# 0          1                 31  10:17 AM  10:16 PM  ...         18
# 1          1                 31  10:17 AM  10:16 PM  ...         18
# 2          1                 31  10:17 AM  10:16 PM  ...         18
# 3          1                 31  10:17 AM  10:16 PM  ...         18
# 4          1                 31  10:17 AM  10:16 PM  ...         20
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  96432.000000  96432.000000       96432.0  96432.000000  96432.000000
# mean      30.945495     20.206322           0.0     10.396267      6.134644
# std        4.379970      3.133037           0.0      2.011727      0.932275
# min       20.000000     10.000000           0.0      4.100000      4.000000
# 25%       28.000000     18.000000           0.0      8.700000      5.000000
# 50%       30.000000     21.000000           0.0     11.200000      6.000000
# 75%       34.000000     22.000000           0.0     11.600000      7.000000
# max       42.000000     30.000000           0.0     13.600000      9.000000
#
#           uvIndex.1  moon_illumination     DewPointC    FeelsLikeC  \
# count  96432.000000       96432.000000  96432.000000  96432.000000
# mean       3.903248          46.094077     14.870603     26.552006
# std        3.024399          31.249725      6.320289      4.797706
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96432 entries, 0 to 96431
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          96432 non-null  object
#  1   maxtempC           96432 non-null  int64
#  2   mintempC           96432 non-null  int64
#  3   totalSnow_cm       96432 non-null  float64
#  4   sunHour            96432 non-null  float64
#  5   uvIndex            96432 non-null  int64
#  6   uvIndex.1          96432 non-null  int64
#  7   moon_illumination  96432 non-null  int64
#  8   moonrise           96432 non-null  object
#  9   moonset            96432 non-null  object
#  10  sunrise            96432 non-null  object
#  11  sunset             96432 non-null  object
#  12  DewPointC          96432 non-null  int64
#  13  FeelsLikeC         96432 non-null  int64
#  14  HeatIndexC         96432 non-null  int64
#  15  WindChillC         96432 non-null  int64
# ...

# %%
num_features = df.select_dtypes(include=['int64','float64'])
print(num_features.columns)
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'uvIndex.1', 'moon_illumination', 'DewPointC', 'FeelsLikeC',
#        'HeatIndexC', 'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity',
#        'precipMM', 'pressure', 'tempC', 'visibility', 'winddirDegree',
#        'windspeedKmph'],
#       dtype='object')

# %%
cat_features = df.select_dtypes(include=object).drop(columns=['date_time'])
cat_features.head()
# Out:
#    moonrise   moonset   sunrise    sunset
# 0  10:17 AM  10:16 PM  07:07 AM  06:09 PM
# 1  10:17 AM  10:16 PM  07:07 AM  06:09 PM
# 2  10:17 AM  10:16 PM  07:07 AM  06:09 PM
# 3  10:17 AM  10:16 PM  07:07 AM  06:09 PM
# 4  10:17 AM  10:16 PM  07:07 AM  06:09 PM

# %% [markdown]
# gonna have to convert these to date_time objects to get numerical data so that we can plot it

# %%
ax = plt.axes()
sns.heatmap(df.isna(),cbar=False,ax=ax)
# Out:
# <Axes: >

# %%
df.dropna(axis=0)
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2009-01-01 00:00:00        31        13           0.0     11.0
# 1      2009-01-01 01:00:00        31        13           0.0     11.0
# 2      2009-01-01 02:00:00        31        13           0.0     11.0
# 3      2009-01-01 03:00:00        31        13           0.0     11.0
# 4      2009-01-01 04:00:00        31        13           0.0     11.0
# ...                    ...       ...       ...           ...      ...
# 96427  2020-01-01 19:00:00        29        18           0.0     11.0
# 96428  2020-01-01 20:00:00        29        18           0.0     11.0
# 96429  2020-01-01 21:00:00        29        18           0.0     11.0
# 96430  2020-01-01 22:00:00        29        18           0.0     11.0
# 96431  2020-01-01 23:00:00        29        18           0.0     11.0
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# ...

# %%
for col_name in cat_features.columns:
    no_name = "No " + df[col_name]
    df[col_name] = df[col_name].where(~df[col_name].str.startswith("No "), pd.NA)
    df[col_name] = pd.to_datetime(df[col_name],format = "%I:%M %p",errors="coerce")
    min_name = col_name+"_minutes"
    df[min_name] = df[col_name].dt.hour*60 + df[col_name].dt.minute

# %%
# df['totalSnow_cm']
df=df.drop(['totalSnow_cm'],axis=1)

# %%
df=df.drop(['moonrise', 'moonset', 'sunrise', 'sunset'],axis=1)
df.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'sunHour', 'uvIndex', 'uvIndex.1',
#        'moon_illumination', 'DewPointC', 'FeelsLikeC', 'HeatIndexC',
#        'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity', 'precipMM',
#        'pressure', 'tempC', 'visibility', 'winddirDegree', 'windspeedKmph',
#        'moonrise_minutes', 'moonset_minutes', 'sunrise_minutes',
#        'sunset_minutes'],
#       dtype='object')

# %%
sample_rate = 50
sampled_df = df.iloc[::sample_rate]
fig,ax= plt.subplots(1,4,figsize=(20,7))
plt.subplot(151)
plt.plot(sampled_df['date_time'],sampled_df['moonrise_minutes'])
plt.subplot(152)
plt.plot(sampled_df['date_time'],sampled_df['moonset_minutes'])
plt.subplot(153)
plt.plot(sampled_df['date_time'],sampled_df['sunrise_minutes'])
plt.subplot(154)
plt.plot(sampled_df['date_time'],sampled_df['sunset_minutes'])

# %% [markdown]
# sunrise and sunset are showing seasonality <br> need smoothing to get moonrise moonset
